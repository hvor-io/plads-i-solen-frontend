# %%
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

# %%
dataset = "test.npy"

data = np.load(dataset)

# %%
mask = (data > data.mean())
mask +=  data
data = mask + 0.2*np.random.randn(*mask.shape)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[37], line 2
#       1 mask = (data > data.mean())
# ----> 2 mask +=  data
#       3 data = mask + 0.2*np.random.randn(*mask.shape)
#
# UFuncTypeError: Cannot cast ufunc 'add' output from dtype('int8') to dtype('bool') with casting rule 'same_kind'

# %%
hist, bin_edges = np.histogram(data, bins=5)
bin_centers = 0.5*(bin_edges[:-1] + bin_edges[1:])
binary_img = data > 0.5

# %%
plt.figure(figsize=(11,4))

plt.subplot(131)
plt.imshow(data)
plt.axis('off')
plt.subplot(132)
plt.plot(bin_centers, hist, lw=2)
plt.axvline(0.5, color='r', ls='--', lw=2)
plt.text(0.57, 0.8, 'histogram', fontsize=20, transform = plt.gca().transAxes)
plt.yticks([])
plt.subplot(133)
plt.imshow(binary_img, cmap=plt.cm.gray, interpolation='nearest')
plt.axis('off')

plt.subplots_adjust(wspace=0.02, hspace=0.3, top=1, bottom=0.1, left=0, right=1)
plt.show()

# %%
# https://scipy-lectures.org/advanced/image_processing/#segmentation
